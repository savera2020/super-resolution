# %% [markdown]
# ### Deep Network Cascade for image Super-resolution

# %% [markdown]
# #### NLSS implementation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img_gray = cv2.imread('../image/sky.jpeg',0)

# %%
def gaussiand_2_level_pyramid(img,kernal_size):
    
    blur_1 = cv2.GaussianBlur(img,(kernal_size,kernal_size),0)
    [h,w]  = blur_1.shape
    ## down_sample the blur1 and apply gaussian again 
    d_blur_1 = cv2.resize(blur_1, (0,0), fx=0.5, fy=0.5) 
    d_blur_2 = cv2.GaussianBlur(d_blur_1,(kernal_size,kernal_size),0)
    ## upsample image 
    blur_2 = cv2.resize(d_blur_2,(h,w),0,0, interpolation = cv2.INTER_NEAREST)
    return blur_1, blur_2

# %%
def NLSS_serach(img_gray,patch_size,kernal_size):
    ## apply bicubic interpolation 
    img_gray_scale = cv2.resize(img_gray,(0,0),fx=1.37,fy=1.37, interpolation = cv2.INTER_CUBIC)
    
    [h,w] = img_gray_scale.shape
    out_img = np.zeros([2*h,2*w],dtype='float')
    overalp_size = round(patch_size/2)
    
    i = 0
    for row in range (0,h-patch_size,overalp_size):
        j = 0
        for col in range (0,w-patch_size,overalp_size):
            
            patch = img_gray_scale [row:row+patch_size,col:col+patch_size]
            ## apply blur in pathand perform down sampling 
            blur_1, blur_2 = gaussiand_2_level_pyramid(patch,kernal_size)
            mean_patch = blur_1/2.0 + blur_2/2.0        ## averaging instead of gaussina
            
            mean_patch.shape
            #out_img[row:row+path_size,col:col+path_size] = mean_patch
            out_img[i:i+patch_size,j:j+patch_size] = mean_patch
        
            j = j+patch_size
        i = i+patch_size    
    return out_img

# %%
#blur_1, blur_2 = gaussiand_2_level_pyramid(img_gray,3)

# %%
NLSS_img = NLSS_serach(img_gray,56,5)

# %%
fig=plt.figure(figsize=(16, 16))
columns = 1
rows = 2
fig.add_subplot(rows, columns, 1)
plt.axis("off")
plt.title("gray_image")
plt.imshow(img_gray,cmap='gray')
fig.add_subplot(rows, columns, 2)
plt.axis("off")
plt.title("NLSS_image")
plt.imshow(NLSS_img,cmap='gray')

# %% [markdown]
# ## Autoencoder basic module

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras.datasets import mnist
from tensorflow.python.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D

from tensorflow.python.keras.models import Model,Sequential
from tensorflow.python.keras.optimizers import RMSprop

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# Scales the training and test data to range between 0 and 1.
max_value = float(x_train.max())
x_train = x_train.astype('float32') / max_value
x_test = x_test.astype('float32') / max_value
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 22s 2us/step

# %%
x_train.shape, x_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

(x_train.shape, x_test.shape)
# Out:
# ((60000, 784), (10000, 784))

# %%
x_train = x_train.reshape((len(x_train), 28, 28, 1))
x_test = x_test.reshape((len(x_test), 28, 28, 1))
(x_train.shape, x_test.shape)
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
x_train_noisy = x_train + np.random.normal(loc=0.0, scale=0.5, size=x_train.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)

x_test_noisy = x_test + np.random.normal(loc=0.0, scale=0.5, size=x_test.shape)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %% [markdown]
# ### First we need train the basic autoencoder from SR images and downsample images with gaussian blur sigma=1,5,10.

# %%
##
autoencoder = Sequential()

# Encoder Layers
autoencoder.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=x_train.shape[1:]))
autoencoder.add(MaxPooling2D((2, 2), padding='same'))
autoencoder.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
autoencoder.add(MaxPooling2D((2, 2), padding='same'))

# Decoder Layers
autoencoder.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
autoencoder.add(UpSampling2D((2, 2)))
autoencoder.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
autoencoder.add(UpSampling2D((2, 2)))
autoencoder.add(Conv2D(1, (3, 3), activation='sigmoid', padding='same'))

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                validation_data=(x_test_noisy, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.1700 - val_loss: 0.1181
# Epoch 2/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1128 - val_loss: 0.1085
# Epoch 3/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1072 - val_loss: 0.1043
# Epoch 4/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1043 - val_loss: 0.1023
# Epoch 5/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.1024 - val_loss: 0.1011
# Epoch 6/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.1012 - val_loss: 0.0998
# Epoch 7/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.1002 - val_loss: 0.0993
# Epoch 8/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0995 - val_loss: 0.0990
# Epoch 9/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0988 - val_loss: 0.0979
# Epoch 10/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0984 - val_loss: 0.0973
# Epoch 11/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0979 - val_loss: 0.0970
# Epoch 12/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0975 - val_loss: 0.0969
# Epoch 13/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0972 - val_loss: 0.0968
# Epoch 14/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0969 - val_loss: 0.0962
# Epoch 15/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0967 - val_loss: 0.0965
# Epoch 16/100
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0964 - val_loss: 0.0957
# Epoch 17/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0962 - val_loss: 0.0956
# Epoch 18/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0960 - val_loss: 0.0954
# Epoch 19/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0958 - val_loss: 0.0953
# Epoch 20/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0958 - val_loss: 0.0957
# Epoch 21/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0956 - val_loss: 0.0952
# Epoch 22/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0955 - val_loss: 0.0949
# Epoch 23/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0953 - val_loss: 0.0950
# Epoch 24/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0952 - val_loss: 0.0949
# Epoch 25/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0951 - val_loss: 0.0951
# Epoch 26/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0951 - val_loss: 0.0949
# Epoch 27/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0950 - val_loss: 0.0946
# Epoch 28/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0949 - val_loss: 0.0948
# Epoch 29/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0948 - val_loss: 0.0946
# Epoch 30/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0947 - val_loss: 0.0944
# Epoch 31/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 32/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0946 - val_loss: 0.0943
# Epoch 33/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0945 - val_loss: 0.0944
# Epoch 34/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0945 - val_loss: 0.0944
# Epoch 35/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0944 - val_loss: 0.0944
# Epoch 36/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0944 - val_loss: 0.0942
# Epoch 37/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0944 - val_loss: 0.0943
# Epoch 38/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0943 - val_loss: 0.0944
# Epoch 39/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0943 - val_loss: 0.0944
# Epoch 40/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0942 - val_loss: 0.0942
# Epoch 41/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0941 - val_loss: 0.0940
# Epoch 42/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 43/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0941 - val_loss: 0.0939
# Epoch 44/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 45/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0940 - val_loss: 0.0941
# Epoch 46/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0940 - val_loss: 0.0941
# Epoch 47/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0939 - val_loss: 0.0939
# Epoch 48/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0939 - val_loss: 0.0939
# Epoch 49/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0938 - val_loss: 0.0939
# Epoch 50/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0938 - val_loss: 0.0942
# Epoch 51/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0938 - val_loss: 0.0938
# Epoch 52/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0938 - val_loss: 0.0943
# Epoch 53/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 54/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 55/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0936 - val_loss: 0.0937
# Epoch 56/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0937 - val_loss: 0.0937
# Epoch 57/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0936 - val_loss: 0.0938
# Epoch 58/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0936 - val_loss: 0.0936
# Epoch 59/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0936 - val_loss: 0.0940
# Epoch 60/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0935 - val_loss: 0.0941
# Epoch 61/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0936 - val_loss: 0.0937
# Epoch 62/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 63/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 64/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 65/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0934 - val_loss: 0.0937
# Epoch 66/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0934 - val_loss: 0.0940
# Epoch 67/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0934 - val_loss: 0.0937
# Epoch 68/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0934 - val_loss: 0.0936
# Epoch 69/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 70/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0934 - val_loss: 0.0934
# Epoch 71/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0934 - val_loss: 0.0935
# Epoch 72/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0933 - val_loss: 0.0934
# Epoch 73/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0933 - val_loss: 0.0934
# Epoch 74/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0933 - val_loss: 0.0934
# Epoch 75/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0934 - val_loss: 0.0937
# Epoch 76/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 77/100
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0933 - val_loss: 0.0935
# Epoch 78/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 79/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 80/100
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0932 - val_loss: 0.0937
# Epoch 81/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 82/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0935
# Epoch 83/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0936
# Epoch 84/100
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 85/100
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 86/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0935
# Epoch 87/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 88/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0931 - val_loss: 0.0933
# Epoch 89/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0934
# Epoch 90/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0932 - val_loss: 0.0933
# Epoch 91/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0931 - val_loss: 0.0934
# Epoch 92/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 93/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0931 - val_loss: 0.0934
# Epoch 94/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 95/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0931 - val_loss: 0.0933
# Epoch 96/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 97/100
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 98/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0930 - val_loss: 0.0936
# Epoch 99/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0931 - val_loss: 0.0933
# Epoch 100/100
# 60000/60000 [==============================] - 4s 71us/step - loss: 0.0930 - val_loss: 0.0933

# %% [markdown]
# ## Above is one module of  NLSS with autoencoder . We need to train the full stack of netwotk as it uses back projection like resnet architecture.

# %% [markdown]
# ### Retrain the model with NLSS data set

# %%
## read NLSS input image generate patch and

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=1,
                batch_size=128,
                validation_data=(x_test_noisy, x_test))

# %%
import glob

# %%
# reaf training data #
def load_data_from_images(images_path,label_path):
    
    count = 0
    
    data_images = []
    data_labels = []
    for img_path,label_img_path in zip(glob.glob(images_path),glob.glob(label_path)):
        img = cv2.imread(img_path)
        label_img = cv2.imread(img_path)
        
        img1_d  =img.reshape(1,56*56*3)
        label_img1_d  =label_img.reshape(1,56*56*3)
        
        data_images.append(img1_d)
        data_labels.append(label_img1_d)
        if(img_path.split('/')[0] ==label_img_path.split('/')[0] ):
            #print(count)
            count=count+1
        
    data_images = np.squeeze(np.array(data_images))
    data_labels = np.squeeze(np.array(data_labels))
    
    
    train_data = data_images[0:80000,:]
    test_data = data_images[80000:-1,:]
    
    train_labels = data_labels[0:80000,:]
    test_labels = data_labels[80000:-1,:]
    
    

    
    
    print(train_data.shape,train_labels.shape)       
    print(test_data.shape,test_labels.shape)    
    print(count)    
    return train_data,train_labels,test_data,test_labels

# %%
images_path = '/home/lord/cv_assignment/cv_project/data_set/NLSS_data_set/train/LR/*.jpg'
label_path = '/home/lord/cv_assignment/cv_project/data_set/NLSS_data_set/train/SR/*.jpg'
train_data,train_labels,test_data,test_labels = load_data_from_images(images_path,label_path)

# %%
56*56*3
# Out:
# 9408
